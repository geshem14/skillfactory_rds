# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter

# %%
data = pd.read_csv('data.csv')
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
len(data)
# Out:
# 1890

# %% [markdown]
# # Предобработка датасета

# %%
answer_ls = [] # создадим список с ответами.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1890 entries, 0 to 1889
# Data columns (total 16 columns):
# imdb_id                 1890 non-null object
# popularity              1890 non-null float64
# budget                  1890 non-null int64
# revenue                 1890 non-null int64
# original_title          1890 non-null object
# cast                    1890 non-null object
# director                1890 non-null object
# tagline                 1890 non-null object
# overview                1890 non-null object
# runtime                 1890 non-null int64
# genres                  1890 non-null object
# production_companies    1890 non-null object
# release_date            1890 non-null object
# vote_count              1890 non-null int64
# vote_average            1890 non-null float64
# release_year            1890 non-null int64
# dtypes: float64(2), int64(5), object(9)
# memory usage: 236.4+ KB

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
# тут вводим ваш ответ и добавлем в него список ответов (сейчас для примера стоит "1")
data[data.budget==data.budget.max()]
# Out:
#        imdb_id  popularity     budget   revenue     original_title  \
# 491  tt1032751     0.25054  425000000  11087569  The Warrior's Way
#
#                                                   cast    director  \
# 491  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee
#
#                      tagline  \
# 491  Assassin. Hero. Legend.
#
#                                               overview  runtime  \
# 491  An Asian assassin (Dong-gun Jang) is forced to...      100
#
#                                         genres      production_companies  \
# 491  Adventure|Fantasy|Action|Western|Thriller  Boram Entertainment Inc.
#
#     release_date  vote_count  vote_average  release_year
# 491    12/2/2010          74           6.4          2010

# %%
answer_ls.append('The Warrior\'s Way (tt1032751)')
answer_ls
# Out:
# ["The Warrior's Way (tt1032751)"]

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
data[data.runtime==data.runtime.max()]
# Out:
#         imdb_id  popularity    budget   revenue     original_title  \
# 1158  tt0279111    0.469518  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1158  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1158  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1158  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1158  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_count  vote_average  release_year
# 1158          23           5.8          2003

# %%
answer_ls.append('Gods and Generals (tt0279111)')

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
data[data.runtime==data.runtime.min()]
# Out:
#        imdb_id  popularity    budget   revenue   original_title  \
# 769  tt1449283    1.425344  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 769  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 769  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 769  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 769  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_count  vote_average  release_year
# 769    4/13/2011         174           6.8          2011

# %%
answer_ls.append('Winnie the Pooh tt1449283')

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
data['runtime'].mean()
# Out:
# 109.65343915343915

# %%
answer_ls.append(110)
answer_ls
# Out:
# ["The Warrior's Way (tt1032751)",
#  'Gods and Generals (tt0279111)',
#  'Winnie the Pooh tt1449283',
#  110]

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
data['runtime'].median()
# Out:
# 106.5

# %%
answer_ls.append(106)
answer_ls
# Out:
# ["The Warrior's Way (tt1032751)",
#  'Gods and Generals (tt0279111)',
#  'Winnie the Pooh tt1449283',
#  110,
#  106]

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
data[data.revenue==data.revenue.max()]
# Out:
#        imdb_id  popularity     budget     revenue original_title  \
# 239  tt0499549    9.432768  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  \
# 239  Action|Adventure|Fantasy|Science Fiction
#
#                                   production_companies release_date  \
# 239  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
#
#      vote_count  vote_average  release_year
# 239        8458           7.1          2009

# %%
answer_ls.append('Avatar tt0499549')
answer_ls
# Out:
# ["The Warrior's Way (tt1032751)",
#  'Gods and Generals (tt0279111)',
#  'Winnie the Pooh tt1449283',
#  110,
#  106,
#  'Avatar tt0499549']

# %% [markdown]
# # 7. Какой фильм самый убыточный?
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
data['rev_budg']=data.apply(lambda row: row.revenue - 
                                  row.budget, axis = 1)
data[data.rev_budg==data.rev_budg.min()]
# Out:
#        imdb_id  popularity     budget   revenue     original_title  \
# 491  tt1032751     0.25054  425000000  11087569  The Warrior's Way
#
#                                                   cast    director  \
# 491  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee
#
#                      tagline  \
# 491  Assassin. Hero. Legend.
#
#                                               overview  runtime  \
# 491  An Asian assassin (Dong-gun Jang) is forced to...      100
#
#                                         genres      production_companies  \
# 491  Adventure|Fantasy|Action|Western|Thriller  Boram Entertainment Inc.
#
#     release_date  vote_count  vote_average  release_year   rev_budg
# 491    12/2/2010          74           6.4          2010 -413912431

# %%
answer_ls.append('The Warrior\'s Way tt1032751')

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
data[data.revenue>data.budget].count()
# Out:
# imdb_id                 1478
# popularity              1478
# budget                  1478
# revenue                 1478
# original_title          1478
# cast                    1478
# director                1478
# tagline                 1478
# overview                1478
# runtime                 1478
# genres                  1478
# production_companies    1478
# release_date            1478
# vote_count              1478
# vote_average            1478
# release_year            1478
# rev_budg                1478
# dtype: int64

# %%
answer_ls.append(1478)

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
data_2008=data[data.release_date.str.contains('2008')]
data_2008[data_2008.revenue==data_2008.revenue.max()]
# Out:
#        imdb_id  popularity     budget     revenue   original_title  \
# 600  tt0468569    8.466668  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 600  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 600  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 600      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 600  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_count  vote_average  release_year   rev_budg
# 600        8432           8.1          2008  816921825

# %%
answer_ls.append('The Dark Knight tt0468569')

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
a9=data[data.release_date.str.contains('2012|2013|2014')]
a9[a9.rev_budg==a9.rev_budg.min()]
# Out:
#         imdb_id  popularity     budget   revenue   original_title  \
# 1246  tt1210819     1.21451  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1246  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1246  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1246  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1246  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1246  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_count  vote_average  release_year   rev_budg
# 1246        1607           6.0          2013 -165710090

# %%
answer_ls.append('The Lone Ranger tt1210819')

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
import collections
gen=[]
for g in data.genres:
    str_g=g.split('|')
    for i in str_g:
        gen.append(i)
c = collections.Counter()
for g in gen:
    c[g] += 1
c.most_common(1)
# Out:
# [('Drama', 782)]

# %%
answer_ls.append('Drama')

# %% [markdown]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
import collections
gen=[]
for g in data[data.revenue>data.budget].genres:
    str_g=g.split('|')
    for i in str_g:
        gen.append(i)
c = collections.Counter()
for g in gen:
    c[g] += 1
c.most_common(1)
# Out:
# [('Drama', 560)]

# %%
answer_ls.append('Drama')

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
import collections
dirs=[]
for d in data.director:
    str_d=d.split('|')
    for i in str_d:
        dirs.append(i)
c = collections.Counter()
for d in dirs:
    c[d] += 1
c.most_common(1)
# Out:
# [('Steven Soderbergh', 13)]

# %%
answer_ls.append('Steven Soderbergh')

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
import collections
dirs=[]
for d in data[data.revenue>data.budget].director:
    str_d=d.split('|')
    for i in str_d:
        dirs.append(i)
c = collections.Counter()
for d in dirs:
    c[d] += 1
c.most_common(1)
# Out:
# [('Ridley Scott', 12)]

# %%
answer_ls.append('Ridley Scott')

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
dirs=[]
for d in data.director:
    str_d=d.split('|')
    for i in str_d:
        dirs.append(i)
set_dirs=set(dirs)
len(set_dirs)
sum_for_dir={}
for dir in set_dirs:
    sum_for_dir[dir]=sum(data.rev_budg[data.director==dir])
max(sum_for_dir, key=sum_for_dir.get)#thanks leo022 from stackoverflow.com
# Out:
# 'Peter Jackson'

# %%
answer_ls.append('Peter Jackson')

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
actors=[]
for actor in data.cast:
    str_actor=actor.split('|')
    for i in str_actor:
        actors.append(i)
set_actors=set(actors)
sum_for_actor={}
for a in set_actors:
    sum_for_actor[a]=sum(data.rev_budg[data.cast.str.contains(a)])
max(sum_for_actor, key=sum_for_actor.get)#thanks leo022 from stackoverflow.com
# Out:
# 'Emma Watson'

# %%
answer_ls.append('Emma Watson')

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
movies_2012=data[data.release_year==2012]
actors=[]
for actor in data.cast:
    str_actor=actor.split('|')
    for i in str_actor:
        actors.append(i)
set_actors=set(actors)
actors_value={}
for actor in set_actors:
    actors_value[actor]=sum(movies_2012.rev_budg[movies_2012.cast.str.contains(actor)])
min(actors_value, key=actors_value.get)
# Out:
# 'Kirsten Dunst'

# %%
answer_ls.append('Kirsten Dunst')

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
ab_budget=data[data.budget>data.budget.mean()]
actors=[]
for actor in ab_budget.cast:
    str_actor=actor.split('|')
    for i in str_actor:
        actors.append(i)
import collections
c = collections.Counter()
for a in actors:
    c[a] += 1
c.most_common(1)
# Out:
# [('Matt Damon', 18)]

# %%
answer_ls.append('Matt Damon')

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
nc_movies=data[data.cast.str.contains('Nicolas Cage')]
genres=[]
for g in nc_movies.genres:
    str_gnrs=g.split('|')
    for i in str_gnrs:
        genres.append(i)
c = collections.Counter()
for j in genres:
    c[j] += 1
c.most_common(1)
# Out:
# [('Action', 17)]

# %%
answer_ls.append('Action')

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
comps=[]
for company in data.production_companies:
    str_comps=company.split('|')
    for i in str_comps:
        comps.append(i)
import collections
c = collections.Counter()
for company in comps:
    c[company] += 1
c.most_common(1)
# Out:
# [('Universal Pictures', 173)]

# %%
answer_ls.append('Universal Pictures')

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
#
# 5. Twentieth Century Fox Film Corporation

# %%
comps=[]
movies_2015=data[data.release_year==2015]
for company in movies_2015.production_companies:
    str_comps=company.split('|')
    for i in str_comps:
        comps.append(i)
import collections
c = collections.Counter()
for company in comps:
    c[company] += 1
c.most_common(1)
# Out:
# [('Warner Bros.', 12)]

# %%
answer_ls.append('Warner Bros')

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
comps=[]
comedies=data[data.genres.str.contains('Comedy')]
for company in comedies.production_companies:
    str_comps=company.split('|')
    for i in str_comps:
        comps.append(i)
comp_rev={}
for i in comps:
    comp_rev[i]=comedies[comedies.production_companies.str.contains(i)].rev_budg.sum()
max(comp_rev, key=comp_rev.get)
# Out:
# C:\Users\803513\Anaconda3\lib\site-packages\pandas\core\strings.py:1843: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# 'Universal'

# %%
answer_ls.append('Universal Pictures (Universal)')

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
movies_2012=data[data.release_year==2012]
for company in movies_2012.production_companies:
    str_comps=company.split('|')
    for i in str_comps:
        comps.append(i)
set_comps=set(comps)
comp_rev={}
for i in set_comps:
    comp_rev[i]=movies_2012[movies_2012.production_companies.str.contains(i)]['rev_budg'].sum()
max(comp_rev, key=comp_rev.get)
# Out:
# 'Columbia Pictures'

# %%
answer_ls.append('Columbia Pictures')

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
pp_movies=data[data.production_companies.str.contains('Paramount Pictures')]
pp_movies[pp_movies.rev_budg==pp_movies.rev_budg.min()]
# Out:
#        imdb_id  popularity     budget   revenue        original_title  \
# 926  tt0267626     0.72233  100000000  35168966  K-19: The Widowmaker
#
#                                                   cast         director  \
# 926  Harrison Ford|Liam Neeson|Peter Sarsgaard|Joss...  Kathryn Bigelow
#
#                       tagline  \
# 926  Fate has found its hero.
#
#                                               overview  runtime  \
# 926  When Russia's first nuclear submarine malfunct...      138
#
#                      genres  \
# 926  Thriller|Drama|History
#
#                                   production_companies release_date  \
# 926  Paramount Pictures|Intermedia Films|National G...    7/19/2002
#
#      vote_count  vote_average  release_year  rev_budg
# 926         146           6.0          2002 -64831034

# %%
answer_ls.append('K-19: The Widowmaker tt0267626')

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
years=data.release_year.unique()
y_rev={}
for year in years:
    y_rev[year]=data[data.release_year==year]['rev_budg'].sum()
max(y_rev, key=y_rev.get)
# Out:
# 2015

# %%
answer_ls.append(2015)

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
wb=data[data.production_companies.str.contains('Warner Bros')]
years=data.release_year.unique()
y_rev={}
for y in years:
    y_rev[y]=wb[wb.release_year==y].rev_budg.sum()
max(y_rev, key=y_rev.get)
# Out:
# 2014

# %%
answer_ls.append(2014)

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
#data[data.release_date.str.startswith('5/')].count()
months=[]
for m in data.release_date:
    months.append(m[:2])
import collections
c = collections.Counter()
for m in months:
    c[m]+=1
c.most_common(1)
# Out:
# [('9/', 227)]

# %%
answer_ls.append('Сентябрь')

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
mo=['6/','7/','8/']
cnt_mo=[]
for m in mo:
    cnt_mo.append(data[data.release_date.str.startswith(m)].count())
sum(cnt_mo)
# Out:
# imdb_id                 450
# popularity              450
# budget                  450
# revenue                 450
# original_title          450
# cast                    450
# director                450
# tagline                 450
# overview                450
# runtime                 450
# genres                  450
# production_companies    450
# release_date            450
# vote_count              450
# vote_average            450
# release_year            450
# rev_budg                450
# dtype: int64

# %%
answer_ls.append(450)

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
#winter movies
winter_movies=[]
for w in ['1/','2/','12/']:
    winter_movies.append(data[data.release_date.str.startswith(w)])
win_mov = pd.concat(winter_movies) 
dirs=[]
for d in win_mov.director:
    str_d=d.split('|')
    for i in str_d:
        dirs.append(i)
import collections
c = collections.Counter()
for i in dirs:
    c[i]+=1
c.most_common(1)
# Out:
# [('Peter Jackson', 7)]

# %%
answer_ls.append('Peter Jackson')

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
months=[]
for m in data.release_date:
    months.append(m[:2])
set_months=set(months)
years=[]
for y in data.release_year:
    years.append(y)
set_years=set(years)
m_rev={}
for m in set_months:
    for y in set_years:
        m_rev[m]=data[(data.release_year==y)&data.release_date.str.startswith(m)].revenue.sum()
max(m_rev, key=m_rev.get)
# Out:
# '6/'

# %%
answer_ls.append('Июнь')

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
for company in data.production_companies:
    str_comps=company.split('|')
    for i in str_comps:
        comps.append(i)
set_comps=set(comps)
comp_len={}
data['title_len']=data.apply(lambda row: len(row.original_title), axis = 1)
for comp in set_comps:
    comp_len[comp]=data[data.production_companies.str.contains(comp)].title_len.mean()
max(comp_len, key=comp_len.get)
# Out:
# 'Four By Two Productions'

# %%
answer_ls.append('Four By Two Productions')

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
import re
for company in data.production_companies:
    str_comps=company.split('|')
    for i in str_comps:
        comps.append(i)
set_comps=set(comps)
comp_words={}
data['title_words']=data.apply(lambda row: len(re.findall(r'\w+', row.original_title)), axis = 1)
for comp in set_comps:
    comp_words[comp]=data[data.production_companies.str.contains(comp)].title_words.mean()
max(comp_words, key=comp_words.get)
# Out:
# 'Four By Two Productions'

# %%
answer_ls.append('Four By Two Productions')

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
data_words=[]
for i in data.original_title:
    i_low=i.lower()
    data_words.append(i_low.split())
data_words
d_w=[]
for k in data_words:
    for l in k:
        d_w.append(l)
len(set(d_w))
# Out:
# 2461

# %%
answer_ls.append(2461)

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
one_pcnt = data['vote_average'].value_counts(bins=10)
one_pcnt
# Out:
# (5.7, 6.18]      481
# (6.18, 6.66]     470
# (6.66, 7.14]     277
# (5.22, 5.7]      261
# (4.74, 5.22]     153
# (7.14, 7.62]     144
# (4.26, 4.74]      42
# (7.62, 8.1]       41
# (3.78, 4.26]      15
# (3.294, 3.78]      6
# Name: vote_average, dtype: int64

# %%
data.loc[(data['vote_average'] > one_pcnt.index[7].left) & (data['vote_average'] <= one_pcnt.index[7].right)]
# Out:
#         imdb_id  popularity     budget     revenue  \
# 9     tt2096673    6.326804  175000000   853708609
# 28    tt1895587    4.062293   20000000    88346473
# 34    tt3170832    3.557846    6000000    35401758
# 38    tt1398426    3.202719   28000000   201634991
# 118   tt0816692   24.949134  165000000   621752480
# 119   tt2015381   14.311205  170000000   773312399
# 124   tt2245084    8.691294  165000000   652105443
# 125   tt2084970    8.110711   14000000   233555708
# 128   tt2267998    6.438727   61000000   369330363
# 138   tt2278388    4.930820   30000000   174600318
# 143   tt1631867    3.990452  178000000   370541256
# 151   tt1646971    3.489106  145000000   609123048
# 155   tt2980516    3.170271   15000000   121201940
# 177   tt2582846    2.293859   12000000   305151265
# 240   tt0361748    6.098027   70000000   319131050
# 270   tt1028532    1.575231   16000000    47801389
# 283   tt0485947    1.260010   47000000     3547209
# ...

# %%
answer_ls.append('Inside Out, Gone Girl, 12 Years a Slave')

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
duos=['Johnny Depp & Helena Bonham Carter','Hugh Jackman & Ian McKellen','Vin Diesel & Paul Walker','Adam Sandler & Kevin James',
      'Daniel Radcliffe & Rupert Grint']
duos_cnt={}
for i in duos:
    actor1,actor2=i.split(' & ')
    duos_cnt[i]=len(data[(data.cast.str.contains(actor1))&(data.cast.str.contains(actor2))])
max(duos_cnt, key=duos_cnt.get)
# Out:
# 'Daniel Radcliffe & Rupert Grint'

# %%
answer_ls.append('Daniel Radcliffe & Rupert Grint')

# %% [markdown]
# # 36. У какого из режиссеров самый высокий процент фильмов со сборами выше бюджета? (5 баллов)101
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
dirs=[]
for d in data.director:
    str_d=d.split('|')
    for i in str_d:
        dirs.append(i)
set_dirs=set(dirs)
dir_rev_budg={}
for d in set_dirs:
    dir_rev_budg[d]=len(data[(data.director.str.contains(d))&(data.revenue>data.budget)])/len(data[data.director.str.contains(d)])
#max(dir_rev_budg, key=dir_rev_budg.get) 
for i in dir_rev_budg.keys():
    if i in ['Quentin Tarantino','Steven Soderbergh','Robert Rodriguez','Christopher Nolan','Clint Eastwood']:
        print(i,dir_rev_budg[i])
# Out:
# Clint Eastwood 0.8333333333333334
# Steven Soderbergh 0.7692307692307693
# Christopher Nolan 1.0
# Quentin Tarantino 0.8571428571428571
# Robert Rodriguez 0.7272727272727273

# %%
answer_ls.append('Christopher Nolan')

# %% [markdown]
# # Submission

# %%
len(answer_ls)
# Out:
# 36

# %%
pd.DataFrame({'Id':range(1,len(answer_ls)+1), 'Answer':answer_ls}, columns=['Id', 'Answer'])
# Out:
#     Id                                   Answer
# 0    1            The Warrior's Way (tt1032751)
# 1    2            Gods and Generals (tt0279111)
# 2    3                Winnie the Pooh tt1449283
# 3    4                                      110
# 4    5                                      106
# 5    6                         Avatar tt0499549
# 6    7              The Warrior's Way tt1032751
# 7    8                                     1478
# 8    9                The Dark Knight tt0468569
# 9   10                The Lone Ranger tt1210819
# 10  11                                    Drama
# 11  12                                    Drama
# 12  13                        Steven Soderbergh
# 13  14                             Ridley Scott
# 14  15                            Peter Jackson
# 15  16                              Emma Watson
# 16  17                            Kirsten Dunst
# 17  18                               Matt Damon
# 18  19                                   Action
# ...
