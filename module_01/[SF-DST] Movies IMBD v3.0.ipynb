# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter

# %%
data = pd.read_csv('data.csv')
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
len(data)
# Out:
# 1890

# %% [markdown]
# # Предобработка датасета

# %%
answer_ls = [] # создадим список с ответами. сюда будем добавлять ответы по мере прохождения теста
# сюда можем вписать создание новых колонок в датасете

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1890 entries, 0 to 1889
# Data columns (total 16 columns):
# imdb_id                 1890 non-null object
# popularity              1890 non-null float64
# budget                  1890 non-null int64
# revenue                 1890 non-null int64
# original_title          1890 non-null object
# cast                    1890 non-null object
# director                1890 non-null object
# tagline                 1890 non-null object
# overview                1890 non-null object
# runtime                 1890 non-null int64
# genres                  1890 non-null object
# production_companies    1890 non-null object
# release_date            1890 non-null object
# vote_count              1890 non-null int64
# vote_average            1890 non-null float64
# release_year            1890 non-null int64
# dtypes: float64(2), int64(5), object(9)
# memory usage: 236.4+ KB

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
# тут вводим ваш ответ и добавлем в него список ответов (сейчас для примера стоит "1")
a1=data[data.budget==data.budget.max()]
a1
# Out:
#        imdb_id  popularity     budget   revenue     original_title  \
# 491  tt1032751     0.25054  425000000  11087569  The Warrior's Way
#
#                                                   cast    director  \
# 491  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee
#
#                      tagline  \
# 491  Assassin. Hero. Legend.
#
#                                               overview  runtime  \
# 491  An Asian assassin (Dong-gun Jang) is forced to...      100
#
#                                         genres      production_companies  \
# 491  Adventure|Fantasy|Action|Western|Thriller  Boram Entertainment Inc.
#
#     release_date  vote_count  vote_average  release_year
# 491    12/2/2010          74           6.4          2010

# %%
answer_ls.append('The Warrior\'s Way (tt1032751)')

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
a2=data[data.runtime==data.runtime.max()]
a2
# Out:
#         imdb_id  popularity    budget   revenue     original_title  \
# 1158  tt0279111    0.469518  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1158  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1158  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1158  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1158  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_count  vote_average  release_year
# 1158          23           5.8          2003

# %%
answer_ls.append('Gods and Generals (tt0279111)')

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
a3=data[data.runtime==data.runtime.min()]
a3
# Out:
#        imdb_id  popularity    budget   revenue   original_title  \
# 769  tt1449283    1.425344  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 769  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 769  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 769  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 769  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_count  vote_average  release_year
# 769    4/13/2011         174           6.8          2011

# %%
answer_ls.append('Winnie the Pooh tt1449283')

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
a4=data['runtime'].mean()
a4
# Out:
# 109.65343915343915

# %%
answer_ls.append(110)
answer_ls
# Out:
# ["The Warrior's Way (tt1032751)",
#  'Gods and Generals (tt0279111)',
#  'Winnie the Pooh tt1449283',
#  110]

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
a5=data['runtime'].median()
a5
# Out:
# 106.5

# %%
answer_ls.append(106)
answer_ls
# Out:
# ["The Warrior's Way (tt1032751)",
#  'Gods and Generals (tt0279111)',
#  'Winnie the Pooh tt1449283',
#  110,
#  106]

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
a6=data[data.revenue==data.revenue.max()]
a6
# Out:
#        imdb_id  popularity     budget     revenue original_title  \
# 239  tt0499549    9.432768  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  \
# 239  Action|Adventure|Fantasy|Science Fiction
#
#                                   production_companies release_date  \
# 239  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
#
#      vote_count  vote_average  release_year
# 239        8458           7.1          2009

# %%
answer_ls.append('Avatar tt0499549')

# %% [markdown]
# # 7. Какой фильм самый убыточный?
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
a7=data[data.revenue==data.revenue.min()]#####???????????????????????????????????????The Adventures of Pluto Nash tt0180052
a7
# Out:
#        imdb_id  popularity   budget  revenue     original_title  \
# 713  tt0490181     0.32288  8000000  2033165  Mutant Chronicles
#
#                                                   cast      director  \
# 713  Ron Perlman|Thomas Jane|Devon Aoki|Sean Pertwe...  Simon Hunter
#
#                                               tagline  \
# 713  Welcome to the 23rd century.  The new dark ages.
#
#                                               overview  runtime  \
# 713  It's the year 2707. Earth's natural resources ...      111
#
#                                       genres  \
# 713  Action|Adventure|Horror|Science Fiction
#
#                                   production_companies release_date  \
# 713  Isle of Man Film|Edward R. Pressman Film|Parad...     8/7/2008
#
#      vote_count  vote_average  release_year
# 713          61           5.1          2008

# %%
answer_ls.append('The Adventures of Pluto Nash tt0180052')

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
a8=data[data.revenue>data.budget].count()
a8
# Out:
# imdb_id                 1478
# popularity              1478
# budget                  1478
# revenue                 1478
# original_title          1478
# cast                    1478
# director                1478
# tagline                 1478
# overview                1478
# runtime                 1478
# genres                  1478
# production_companies    1478
# release_date            1478
# vote_count              1478
# vote_average            1478
# release_year            1478
# dtype: int64

# %%
answer_ls.append(1478)

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
a9=data[data.release_date.str.contains('2008')]
a9
# Out:
#        imdb_id  popularity     budget     revenue  \
# 600  tt0468569    8.466668  185000000  1001921825
# 601  tt0910970    5.678119  180000000   521311860
# 602  tt0371746    4.977955  140000000   585174222
# 603  tt0936501    3.647612   25000000   226830568
# 604  tt0367882    3.161670  185000000   786636033
# ..         ...         ...        ...         ...
# 716  tt0858479    0.278543    7000000    10569964
# 717  tt0410377    0.768409   37000000   100076342
# 718  tt0465502    0.259988   25000000    30000000
# 719  tt0455538    0.659884   27000000    17286299
# 720  tt0494652    0.224471   35000000    43650785
#
#                                         original_title  \
# 600                                    The Dark Knight
# 601                                            WALLÂ·E
# 602                                           Iron Man
# 603                                              Taken
# 604  Indiana Jones and the Kingdom of the Crystal S...
# ...

# %%
answer_ls.append('The Dark Knight tt0468569')

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
a9=data[data.release_date.str.contains('2012')]
a9
# Out:
#         imdb_id  popularity     budget     revenue  \
# 971   tt0848228    7.637767  220000000  1519557910
# 972   tt1496025    7.031452   70000000   132400000
# 973   tt1345836    6.591277  250000000  1081041287
# 974   tt1853728    5.944518  100000000   425368238
# 975   tt1074638    5.603587  200000000  1108561013
# ...         ...         ...        ...         ...
# 1077  tt1433822    0.398497   17000000     9627492
# 1078  tt1480656    0.359578   20500000     6063556
# 1079  tt1855325    0.260624   65000000   240159255
# 1080  tt1876451    0.308684   14000000    24637469
# 1081  tt2215719    0.050524   12000000    32726956
#
#                   original_title  \
# 971                 The Avengers
# 972        Underworld: Awakening
# 973        The Dark Knight Rises
# 974             Django Unchained
# 975                      Skyfall
# ...                          ...
# 1077              The Apparition
# 1078                  Cosmopolis
# 1079  Resident Evil: Retribution
# ...

# %%
answer_ls.append('Stolen tt1656186')

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
action_cnt=data[data.genres.str.contains('Thriller')].count()
action_cnt
# Out:
# imdb_id                 597
# popularity              597
# budget                  597
# revenue                 597
# original_title          597
# cast                    597
# director                597
# tagline                 597
# overview                597
# runtime                 597
# genres                  597
# production_companies    597
# release_date            597
# vote_count              597
# vote_average            597
# release_year            597
# dtype: int64

# %%
answer_ls.append('Drama')

# %% [markdown]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
a12=data[data.revenue>data.budget]
cnt=a12[a12.genres.str.contains('Adventure')].count()
cnt
# Out:
# imdb_id                 337
# popularity              337
# budget                  337
# revenue                 337
# original_title          337
# cast                    337
# director                337
# tagline                 337
# overview                337
# runtime                 337
# genres                  337
# production_companies    337
# release_date            337
# vote_count              337
# vote_average            337
# release_year            337
# dtype: int64

# %%
answer_ls.append('Drama')

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
ss=data[data.director=='Steven Soderbergh'].count()
ss
# Out:
# imdb_id                 13
# popularity              13
# budget                  13
# revenue                 13
# original_title          13
# cast                    13
# director                13
# tagline                 13
# overview                13
# runtime                 13
# genres                  13
# production_companies    13
# release_date            13
# vote_count              13
# vote_average            13
# release_year            13
# dtype: int64

# %%
answer_ls.append('Steven Soderbergh')

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
a14=data[data.revenue>data.budget]
cnt_dirs=a14[a14.director=='Christopher Nolan'].count()
cnt_dirs
# Out:
# imdb_id                 8
# popularity              8
# budget                  8
# revenue                 8
# original_title          8
# cast                    8
# director                8
# tagline                 8
# overview                8
# runtime                 8
# genres                  8
# production_companies    8
# release_date            8
# vote_count              8
# vote_average            8
# release_year            8
# dtype: int64

# %%
answer_ls.append('Ridley Scott')

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
data[data.director=='Steven Spielberg']['revenue'].max()
# Out:
# 786636033

# %%
answer_ls.append('James Cameron')

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
answer_ls.append('Johnny Depp')

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
movies_2012=data[data.release_year==2012].sort_values('revenue', ascending=True)
movies_2012
# Out:
#         imdb_id  popularity     budget     revenue  \
# 1034  tt1656186    1.157127   35000000     2106557
# 1049  tt1433811    0.903283   10000000     3428048
# 1076  tt1925431    0.409718   20000000     4636169
# 1078  tt1480656    0.359578   20500000     6063556
# 1008  tt1374992    1.690572   60000000     8106475
# ...         ...         ...        ...         ...
# 985   tt1667889    3.135776   95000000   877244782
# 977   tt0903624    4.218933  250000000  1017003568
# 973   tt1345836    6.591277  250000000  1081041287
# 975   tt1074638    5.603587  200000000  1108561013
# 971   tt0848228    7.637767  220000000  1519557910
#
#                          original_title  \
# 1034                             Stolen
# 1049                         Disconnect
# 1076                     Fire with Fire
# 1078                         Cosmopolis
# 1008                        Upside Down
# ...                                 ...
# 985          Ice Age: Continental Drift
# ...

# %%
answer_ls.append('Nicolas Cage')

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
av_budget=data.budget.mean()
av_budget
# Out:
# 54506961.474603176

# %%
above_budget=data[data.budget>data.budget.mean()]['cast']
cnt_TC=0
for i in above_budget:
    if 'Matt Damon' in i:
        cnt_TC+=1
cnt_TC
# Out:
# 18

# %%
answer_ls.append('Matt Damon')

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
nc_m=data[data.cast.str.contains('Nicolas Cage')]
gnr=['Drama', 'Action','Thriller', 'Adventure', 'Crime']
nc_m[nc_m.genres.str.contains("Action")].count()
# Out:
# imdb_id                 17
# popularity              17
# budget                  17
# revenue                 17
# original_title          17
# cast                    17
# director                17
# tagline                 17
# overview                17
# runtime                 17
# genres                  17
# production_companies    17
# release_date            17
# vote_count              17
# vote_average            17
# release_year            17
# dtype: int64

# %%
answer_ls.append('Action')

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
a20=data[data.production_companies.str.contains('Universal Pictures')].count()
a20
# Out:
# imdb_id                 175
# popularity              175
# budget                  175
# revenue                 175
# original_title          175
# cast                    175
# director                175
# tagline                 175
# overview                175
# runtime                 175
# genres                  175
# production_companies    175
# release_date            175
# vote_count              175
# vote_average            175
# release_year            175
# dtype: int64

# %%
answer_ls.append('Universal Pictures')

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
a21=data[(data.release_year==2015) & (data.production_companies.str.contains('Universal Pictures'))].count()
a21
# Out:
# imdb_id                 11
# popularity              11
# budget                  11
# revenue                 11
# original_title          11
# cast                    11
# director                11
# tagline                 11
# overview                11
# runtime                 11
# genres                  11
# production_companies    11
# release_date            11
# vote_count              11
# vote_average            11
# release_year            11
# dtype: int64

# %%
answer_ls.append('Universal Pictures')

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
a22=data[(data.genres.str.contains('Comedy'))&(data.production_companies.str.contains('Disney'))].count()
a22
# Out:
# imdb_id                 47
# popularity              47
# budget                  47
# revenue                 47
# original_title          47
# cast                    47
# director                47
# tagline                 47
# overview                47
# runtime                 47
# genres                  47
# production_companies    47
# release_date            47
# vote_count              47
# vote_average            47
# release_year            47
# dtype: int64

# %%
answer_ls.append('Columbia Pictures')

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
companies=['Universal','Warner Bros','Columbia','Paramount','Lucasfilm']
for comp in companies:
    rev_2012=data[(data.release_year==2012)&(data.production_companies.str.contains(comp))]['revenue'].sum()
    print(rev_2012)
# Out:
# 2901011579
# 1869520056
# 3468406608
# 606726715
# 50365377

# %%
answer_ls.append('Columbia Pictures')

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
data[data.production_companies.str.contains('Paramount Pictures')].sort_values('revenue', ascending=True)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 436   tt0964517    1.054685   25000000     9190869
# 960   tt0267248    0.246694   25000000    10719357
# 1069  tt1663143    0.615971   14000000    11417362
# 1391  tt0384680    0.707056   20000000    12482775
# 1661  tt0324127    0.308525   27000000    13000000
# ...         ...         ...        ...         ...
# 731   tt1229238    2.952740  145000000   694713380
# 1739  tt0418279    0.890557  150000000   709709780
# 604   tt0367882    3.161670  185000000   786636033
# 317   tt1055369    0.813323  150000000   836297228
# 829   tt1399103    0.760503  195000000  1123746996
#
#                                          original_title  \
# 436                                         The Fighter
# 960                                             Abandon
# 1069                                           Fun Size
# 1391                                    The Weather Man
# 1661                                       Suspect Zero
# ...

# %%
answer_ls.append('The Fighter tt0964517')

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
data.groupby(['release_year'])['revenue'].sum()
# Out:
# release_year
# 2000    10664099805
# 2001    13017764865
# 2002    14136361487
# 2003    14346123312
# 2004    15663430720
# 2005    15309425558
# 2006    14775042320
# 2007    18162406801
# 2008    18252781990
# 2009    20261791024
# 2010    21082292530
# 2011    22676791872
# 2012    23079001687
# 2013    23213799791
# 2014    23405862953
# 2015    25449202382
# Name: revenue, dtype: int64

# %%
answer_ls.append(2015)

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
wb=data[data.production_companies.str.contains('Warner Bros')]
wb.groupby(['release_year'])['revenue'].sum().sort_values(ascending=False)
#wb.groupby('release_year')
# Out:
# release_year
# 2014    3243064519
# 2007    3183675217
# 2008    3050595031
# 2010    3008712985
# 2011    2845393682
# 2003    2745493377
# 2009    2737954136
# 2004    2731933725
# 2013    2599953400
# 2005    2412980298
# 2001    2266545668
# 2012    1869520056
# 2002    1702709901
# 2015    1691168351
# 2006    1521170743
# 2000    1025531386
# Name: revenue, dtype: int64

# %%
answer_ls.append(2014)

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
data[data.release_date.str.startswith('5/')].count()
# Out:
# imdb_id                 140
# popularity              140
# budget                  140
# revenue                 140
# original_title          140
# cast                    140
# director                140
# tagline                 140
# overview                140
# runtime                 140
# genres                  140
# production_companies    140
# release_date            140
# vote_count              140
# vote_average            140
# release_year            140
# dtype: int64

# %%
answer_ls.append('Сентябрь')

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
mo=['6/','7/','8/']
cnt_mo=0
for m in mo:
    cnt_mo+=data[data.release_date.str.startswith(m)].count()
    print(cnt_mo)
# Out:
# imdb_id                 147
# popularity              147
# budget                  147
# revenue                 147
# original_title          147
# cast                    147
# director                147
# tagline                 147
# overview                147
# runtime                 147
# genres                  147
# production_companies    147
# release_date            147
# vote_count              147
# vote_average            147
# release_year            147
# dtype: int64
# imdb_id                 289
# popularity              289
# budget                  289
# revenue                 289
# original_title          289
# cast                    289
# director                289
# tagline                 289
# overview                289
# runtime                 289
# genres                  289
# production_companies    289
# release_date            289
# vote_count              289
# vote_average            289
# release_year            289
# dtype: int64
# ...

# %%
answer_ls.append(450)

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
dir_movies=data[(data.director=='Peter Jackson')&(data.release_date.str.startswith('1/'))].count()
dir_movies
# Out:
# imdb_id                 0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# director                0
# tagline                 0
# overview                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# dtype: int64

# %%
answer_ls.append('Peter Jackson')

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
a30=data[data.release_date.str.startswith('12/')].groupby(['release_year'])
a30.revenue.sum().mean()
# Out:
# 2424116967.125

# %%
answer_ls.append('Декабрь')

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
data[data.production_companies.str.contains('Four By Two Productions')]['original_title'].str.len().sum()
# Out:
# 83

# %%
answer_ls.append('Four By Two Productions')

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
data[data.production_companies.str.contains('Four By Two Productions')]['original_title']
# Out:
# 1449    Borat: Cultural Learnings of America for Make ...
# Name: original_title, dtype: object

# %%
answer_ls.append('Four By Two Productions')

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
data_words=[]
for i in data.original_title:
    i_low=i.lower()
    data_words.append(i_low.split())
data_words
d_w=[]
for k in data_words:
    for l in k:
        d_w.append(l)
len(set(d_w))
# Out:
# 2461

# %%
answer_ls.append(2461)

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
data[data.vote_average==data.vote_average.max()]
# Out:
#        imdb_id  popularity     budget     revenue   original_title  \
# 600  tt0468569    8.466668  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 600  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 600  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 600      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 600  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_count  vote_average  release_year
# 600        8432           8.1          2008

# %%
data[data.original_title=='Lucky Number Slevin']
# Out:
#         imdb_id  popularity    budget   revenue       original_title  \
# 1457  tt0425210    1.520387  27000000  56308881  Lucky Number Slevin
#
#                                                    cast       director  \
# 1457  Josh Hartnett|Bruce Willis|Lucy Liu|Morgan Fre...  Paul McGuigan
#
#                                      tagline  \
# 1457  Wrong Time. Wrong Place. Wrong Number.
#
#                                                overview  runtime  \
# 1457  Slevin is mistakenly put in the middle of a pe...      110
#
#                             genres  \
# 1457  Drama|Thriller|Crime|Mystery
#
#                                    production_companies release_date  \
# 1457  The Weinstein Company|FilmEngine|Capitol Films...    2/24/2006
#
#       vote_count  vote_average  release_year
# 1457         787           7.3          2006

# %%
answer_ls.append('Inside Out, Gone Girl, 12 Years a Slave')

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
a35=data[(data.cast.str.contains('Daniel Radcliffe'))&(data.cast.str.contains('Rupert Grint'))]
len(a35)
# Out:
# 8

# %%
answer_ls.append('Daniel Radcliffe & Rupert Grint')

# %% [markdown]
# # 36. У какого из режиссеров выше вероятность выпустить фильм в прибыли? (5 баллов)101
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
answer_ls.append('Christopher Nolan')

# %% [markdown]
# # Submission

# %%
len(answer_ls)
# Out:
# 36

# %%
pd.DataFrame({'Id':range(1,len(answer_ls)+1), 'Answer':answer_ls}, columns=['Id', 'Answer'])
# Out:
#     Id                                   Answer
# 0    1            The Warrior's Way (tt1032751)
# 1    2            Gods and Generals (tt0279111)
# 2    3                Winnie the Pooh tt1449283
# 3    4                                      110
# 4    5                                      106
# 5    6                         Avatar tt0499549
# 6    7   The Adventures of Pluto Nash tt0180052
# 7    8                                     1478
# 8    9                The Dark Knight tt0468569
# 9   10                         Stolen tt1656186
# 10  11                                    Drama
# 11  12                                    Drama
# 12  13                        Steven Soderbergh
# 13  14                             Ridley Scott
# 14  15                            James Cameron
# 15  16                              Johnny Depp
# 16  17                             Nicolas Cage
# 17  18                               Matt Damon
# 18  19                                   Action
# ...
